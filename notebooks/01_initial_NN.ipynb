# %%
from math import pi
import torch
import torch.nn as nn
import torch.optimal as optim

# %% [markdown]
# ## Test Neural Network

# %%
x = torch.linspace(-5, 5, 100).unsqueeze(1)      # 100 points column
y =
