# %% [markdown]
# # Presentation draft
#
# Notebook de trabajo para preparar una presentacion tipo Beamer. Por ahora solo agrupa las figuras retiradas de la memoria, organizadas por capitulo.
#
# Las figuras CaNN usan la salida actualizada `outputs/calibration/Liu_like_tanh_1M_v01/Calibration_1`.

# %% [markdown]
# ## Chapter 4 - Neural Calibration as an Inverse Problem

# %% [markdown]
# ### Fig. 4.2 - CaNN residual map
#
# <img src="../thesis/figures/cann/cann_residual_heatmap_m_tau_no_reg_smooth.png" style="width:92%; display:block; margin:auto;">
#
# Signed implied-volatility residuals, `IV_pred - IV_market`, from the updated tanh CaNN run.

# %% [markdown]
# ### Fig. 4.3 - CaNN first-order diagnostic
#
# <img src="../thesis/figures/cann/jacobian_theta_star_no_reg.png" style="width:86%; display:block; margin:auto;">
#
# Objective-gradient components at the calibrated solution.

# %% [markdown]
# ### Fig. 4.4 - CaNN local curvature
#
# <img src="../thesis/figures/cann/hessian_theta_star_no_reg.png" style="width:78%; display:block; margin:auto;">
#
# Hessian diagnostic at the calibrated solution.

# %% [markdown]
# ### CaNN to PINN interface
#
# <img src="../thesis/figures/cann/cann_to_pinn_interface.png" style="width:88%; display:block; margin:auto;">
#
# Interface between the calibrated Heston vector and the downstream PINN input convention.

# %% [markdown]
# ## Chapter 6 - Neural Network Performance and Benchmarking

# %% [markdown]
# ### Fig. 6.2 - ANN regional error profile
#
# <img src="../thesis/figures/nn/eval_region_mse.png" style="width:94%; display:block; margin:auto;">
#
# Regional ANN MSE by moneyness and maturity bins.

# %% [markdown]
# ### Fig. 6.3 - CaNN residual map
#
# <img src="../thesis/figures/cann/cann_residual_heatmap_m_tau_no_reg_smooth.png" style="width:92%; display:block; margin:auto;">
#
# Same updated CaNN residual diagnostic as Fig. 4.2, kept here for the benchmark narrative.

# %% [markdown]
# ### Fig. 6.4 - CaNN first-order diagnostic
#
# <img src="../thesis/figures/cann/jacobian_theta_star_no_reg.png" style="width:86%; display:block; margin:auto;">
#
# Same updated CaNN gradient diagnostic as Fig. 4.3.

# %% [markdown]
# ### Fig. 6.5 - CaNN local curvature
#
# <img src="../thesis/figures/cann/hessian_theta_star_no_reg.png" style="width:78%; display:block; margin:auto;">
#
# Same updated CaNN Hessian diagnostic as Fig. 4.4.

# %% [markdown]
# ### Fig. 6.11 - Sobolev training trajectory
#
# <img src="../thesis/figures/pinn/greeks/sobolev_loss_curve.png" style="width:94%; display:block; margin:auto;">
#
# Training loss trajectory with the Sobolev phase switch.
